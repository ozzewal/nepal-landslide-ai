# %%
print("Nepal Landslide Predictor v1.0")
rainfall = float(input("Enter rainfall (mm): "))
slope = float(input("Enter slope angle (degrees): "))
risk = (rainfall * 0.4) + (slope * 0.6)  # Basic risk formula
print(f"Landslide Risk: {risk:.2f}% (0-100 scale)")
# Out:
# Nepal Landslide Predictor v1.0
# Enter rainfall (mm): 60
# Enter slope angle (degrees): 30.5
# Landslide Risk: 42.30% (0-100 scale)
